# %% [markdown]
# ## Create a string s containing your full name. Print the string.

# %%
s= ("Abdullah")
print(s)
# Out:
# Abdullah

# %% [markdown]
# ## Create a string s with a sentence of your choice and print its length.

# %%
s=input("Enter Your Sentence :")
print(len(s))
# Out:
# Enter Your Sentence : Cristiano Ronaldo, who was named after U.S. President Ronald Reagan, has scored over 900 official senior career goals for club and country, becoming the first player in history to achieve this feat.
# 198

# %% [markdown]
# ## Assign a string to a variable and check its data type using Python

# %%
a=("I am Doing good")
print(type(a))
# Out:
# <class 'str'>

# %% [markdown]
# ## Create a variable word with the value "Python" and print the first character.

# %%
word=("Python")
print(word[0])
# Out:
# P

# %% [markdown]
# ## Create a variable course with the value "Python" and print the character at index 3.

# %%
course=("Python")
print(course[3])
# Out:
# h

# %% [markdown]
# ## Create a variable framework with the value "TensorFlow" and print the character at negative index -4.

# %%
framework=("TensorFlow")
print(framework[-4])
# Out:
# F

# %% [markdown]
# ## Create a variable fruit with the value "Apple". Convert the string to uppercase and print it.

# %%
fruit=("Apple")
print(fruit.upper())
# Out:
# APPLE

# %% [markdown]
# ## Create a variable city with the value "Karachi". Convert the string to lowercase and print it.

# %%
city=("Karachi")
print(city.lower())
# Out:
# karachi

# %% [markdown]
# ## Create a variable framework with the value "Django". Check if the string starts with "D" and print True or False.

# %%
framework=("Django")
print(framework.startswith("D"))
# Out:
# True

# %% [markdown]
# ## Create a variable subject with the value "Mathematics". Check if all characters are alphabetic and print True or False.

# %%
subject=("Mathematics")
print(subject.isalpha())
# Out:
# True

# %% [markdown]
# ## Ask the user to enter their email in any format.
# ## and then Convert it into lowercase.

# %%
email=input("Enter Your email :")
print(email.lower())
# Out:
# Enter Your email : ABDULlabalamgir295@Gmail.com
# abdullabalamgir295@gmail.com

# %% [markdown]
# # check if a number is even or odd where number is taken as input

# %%
num_1=int(input("Enter Your Number : "))
if num_1 % 2 == 0 :
    print("Even")
else:
    print("Odd")
# Out:
# Enter Your Number :  77
# Odd

# %% [markdown]
# # User se number lo:
#
# # agar number > 0 → "Positive"
# # warna → "Negative"

# %%
number = int(input("Enter a number: "))

if number > 0:
    print("Positive")
else:
    print("Negative")
# Out:
# Enter a number:  009
# Positive

# %% [markdown]
# # User se password lo:
#
# # agar "python123" hai → "Access Granted"
# # warna → "Access Denied"

# %%
password=input("Enetr Password :")
if password == "python123":
    print("Access Granted")
else:
    print("Access Deined")
# Out:
# Enetr Password : python123
# Access Granted

# %% [markdown]
# # User se temperature lo:
#
# # agar > 30 → "Hot"
# # warna → "Normal"

# %%
temperature=int(input("Enter Temperature :"))
if temperature > 30 :
    print("HOT")
else:
    print("Normal")
# Out:
# Enter Temperature : 45
# HOT

# %% [markdown]
# # User se naam lo:
# # agar naam "Ali" hai → "Welcome Ali"
# # warna → "Welcome User"

# %%
name=input("Enter Your Name :")
if name == "Ali":
    print("Welcome Ali")
else:
    print("Welcome User")
# Out:
# Enter Your Name : Abdullah
# Welcome User

# %% [markdown]
# # User se marks lo aur grade do:
#
# # 90+ → A
# # 80+ → B
# # 70+ → C
# # 60+ → D
# # warna → Fail

# %%
marks=int(input("Enter Your Marks :"))
if marks >= 90:
    print("Grade A")
elif marks >= 80:
    print("Grade B")
elif marks >= 70:
    print("Grade C")
elif marks >= 60:
    print("Grade D")
else:
    print("Fail")
# Out:
# Enter Your Marks : 78
# Grade C

# %% [markdown]
# # User se day number (1–7) lo:
#
# # 1 → Monday
# # 2 → Tuesday
# ## ...
# # 7 → Sunday

# %%
day_number = int(input("Enter Your day number :"))
if day_number ==1:
    print("Monday")
elif day_number ==2:
    print("Tuesday")
elif day_number ==3:
    print("Wednesday")
elif day_number ==4:
    print("Thursday")
elif day_number ==5:
    print("Friday")
elif day_number ==6:
    print("Saturday")
else:
    print("Sunday")
# Out:
# Enter Your day number : 7
# Sunday

# %% [markdown]
# # User se month number lo:
#
# # 12,1,2 → Winter
# # 3,4,5 → Spring
# # 6,7,8 → Summer
# # warna → Autumn

# %%
month_number=int(input("Enter Month Number (1-12):"))
if month_number in [12,1,2]:
    print("Winter")
elif month_number in [3,4,5]:
    print("Spring")
elif month_number in [6,7,8]:
    print("Summer")
else:
    print("Autumn")
# Out:
# Enter Month Number (1-12): 8
# Summer

# %% [markdown]
# # User se 2 numbers lo:
#
# # pehla > dusra → "First is greater"
# # pehla < dusra → "Second is greater"
# # warna → "Both equal"

# %%
number_1=int(input("Enter First Number :"))
number_2=int(input("Enter Second NUmber :"))
if number_1 > number_2:
    print("First is greater")
elif number_1 < number_2:
    print("Second is greater")
else:
    print("Both equal")
# Out:
# Enter First Number : 87
# Enter Second NUmber : 98
# Second is greater

# %% [markdown]
# # Simple calculator:
# # User se operator lo (+, -, *, /):
#
# # → addition
# # → subtraction
# # → multiplication
# # / → division
# # warna → "Invalid operator"

# %%
operator = (input("Enter the operator(+,-,*,/):"))
if operator == "+":
    print("Addition")
elif operator == "-":
    print("Subtraction")
elif operator == "*":
    print("Multiplication")
elif operator == "/":
    print("Division")
else:
    print("Invalid Operator")
# Out:
# Enter the operator(+,-,*,/): *
# Multiplication
